# %% [markdown]
# ### 5 Number Summary and Box Plot
#
# 1. Minimum
# 2. Maximum
# 3. Median
# 4. Q1
# 5. Q3
# 6. IQR

# %%
import numpy as np

# %%
lst_marks = [45,25,36,77,55,69,96,33,44,60,12,100,99,65,79,26,31]
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks, [0,0.25,0.50,0.75,1.0])

# %%
print(f"minimum: {minimum}\nQ1: {Q1}\nmedian: {median}\nQ3: {Q3}\nmaximum: {maximum}")
# Out:
# minimum: 12.0
# Q1: 33.0
# median: 55.0
# Q3: 77.0
# maximum: 100.0

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 44.0

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*(IQR)
print(lower_fence, higher_fence)
# Out:
# -33.0 143.0

# %%
lst_marks = [45,25,36,77,55,69,96,33,44,60,12,100,99,65,79,26,31]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-250,-150,-200,45,25,36,77,55,69,96,33,44,60,12,100,99,65,79,26,31,150,200,250]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
